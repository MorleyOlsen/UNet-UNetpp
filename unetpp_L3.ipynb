# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, UpSampling2D, Reshape, Permute, Activation, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
# Out:
# 2024-03-23 15:28:16.376657: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-23 15:28:17.615563: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-23 15:28:18.167589: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18512 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6

# %%
img_x, img_y = (576, 576)
dx = 48
filelst = os.listdir(r'DRIVE/training/images/')
filelst = ['DRIVE/training/images/'+v for v in filelst]
imgs = [cv2.imread(file) for file in filelst]
filelst = os.listdir(r'DRIVE/training/1st_manual/')
filelst = ['DRIVE/training/1st_manual/'+v for v in filelst]
manuals = [np.asarray(Image.open(file)) for file in filelst]
imgs = [cv2.resize(v,(img_x, img_y)) for v in imgs]
manuals = [cv2.resize(v,(img_x, img_y)) for v in manuals]
X_train = np.array(imgs)  
Y_train = np.array(manuals)
X_train = X_train.astype('float32')/255.
Y_train = Y_train.astype('float32')/255.
X_train = X_train[...,1] # the G channel
X_train = np.array([[X_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
Y_train = np.array([[Y_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx*dx)[...,np.newaxis]
temp = 1-Y_train
Y_train = np.concatenate([Y_train,temp],axis=2)

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)


def conv_block(input_tensor, num_filters):
    """构造一个简单的卷积块，包含两个卷积层"""
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(input_tensor)
    x = Dropout(0.2)(x)
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(x)
    return x

def unet_pp(n_ch, patch_height, patch_width):
    inputs = Input(shape=(n_ch, patch_height, patch_width))

    # 编码路径
    x00 = conv_block(inputs, 32)
    p0 = MaxPooling2D((2, 2))(x00)
    x10 = conv_block(p0, 64)
    p1 = MaxPooling2D((2, 2))(x10)
    x20 = conv_block(p1, 128)
    p2 = MaxPooling2D((2, 2))(x20)
    x30 = conv_block(p2, 256)
    p3 = MaxPooling2D((2, 2))(x30)
    x40 = conv_block(p3, 512) # 最底层
    
    # wtf 纯手写中间层啊，草
    x40_up = UpSampling2D(size=(2, 2))(x40)
    x40_up = concatenate([x30,x40_up],axis=1)
    x31 = conv_block(x40_up, 256)
    
    x30_up = UpSampling2D(size=(2, 2))(x30)
    x30_up = concatenate([x20,x30_up],axis=1)
    x21 = conv_block(x30_up, 128)
    
    x20_up = UpSampling2D(size=(2, 2))(x20)
    x20_up = concatenate([x10,x20_up],axis=1)
    x11 = conv_block(x20_up, 64)
    
    x10_up = UpSampling2D(size=(2, 2))(x10)
    x10_up = concatenate([x00,x10_up],axis=1)
    x01 = conv_block(x10_up, 32)
    
    x31_up = UpSampling2D(size=(2, 2))(x31)
    x31_up = concatenate([x21,x31_up],axis=1)
    x31_up = concatenate([x20,x31_up],axis=1)
    x22 = conv_block(x31_up, 128)
    
    x21_up = UpSampling2D(size=(2, 2))(x21)
    x21_up = concatenate([x11,x21_up],axis=1)
    x21_up = concatenate([x10,x21_up],axis=1)
    x12 = conv_block(x21_up, 64)
    
    x11_up = UpSampling2D(size=(2, 2))(x11)
    x11_up = concatenate([x01,x11_up],axis=1)
    x11_up = concatenate([x00,x11_up],axis=1)
    x02 = conv_block(x11_up, 32)
    
    x22_up = UpSampling2D(size=(2, 2))(x22)
    x22_up = concatenate([x12,x22_up],axis=1)
    x22_up = concatenate([x11,x22_up],axis=1)
    x22_up = concatenate([x10,x22_up],axis=1)
    x13 = conv_block(x22_up, 64)
    
    x12_up = UpSampling2D(size=(2, 2))(x12)
    x12_up = concatenate([x02,x12_up],axis=1)
    x12_up = concatenate([x01,x12_up],axis=1)
    x12_up = concatenate([x00,x12_up],axis=1)
    x03 = conv_block(x12_up, 32)
    
    x13_up = UpSampling2D(size=(2, 2))(x13)
    x13_up = concatenate([x03,x13_up],axis=1)
    x13_up = concatenate([x02,x13_up],axis=1)
    x13_up = concatenate([x01,x13_up],axis=1)
    x13_up = concatenate([x00,x13_up],axis=1)
    x04 = conv_block(x13_up, 32)
    
    # 最终层
    final_1 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x01)
    final_1 = Reshape((2,patch_height*patch_width))(final_1)
    final_1 = Permute((2,1))(final_1)
    final_1 = Activation('softmax')(final_1)
    
    final_2 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x02)
    final_2 = Reshape((2,patch_height*patch_width))(final_2)
    final_2 = Permute((2,1))(final_2)
    final_2 = Activation('softmax')(final_2)
    
    final_3 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x03)
    final_3 = Reshape((2,patch_height*patch_width))(final_3)
    final_3 = Permute((2,1))(final_3)
    final_3 = Activation('softmax')(final_3)
    
    final_4 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x04)
    final_4 = Reshape((2,patch_height*patch_width))(final_4)
    final_4 = Permute((2,1))(final_4)
    final_4 = Activation('softmax')(final_4)
    
    final = [final_1, final_2, final_3, final_4]
    
    # Unet++ L4到L1需要manual modification。
    model = Model(inputs=inputs, outputs=final_3)

    return model
# Out:
# X_train shape: (2880, 1, 48, 48)
# Y_train shape: (2880, 2304, 2)

# %%
# 以下是训练L3的

# %%
model = unet_pp(X_train.shape[1],X_train.shape[2],X_train.shape[3])
model.summary()

# mode = 'max'
checkpointer = ModelCheckpoint(filepath='best_weights.h5', verbose=1, monitor='val_acc', mode='auto', save_best_only=True)
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# 2024-03-23 15:28:27.463392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18512 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1, 48, 48)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 48, 48)   320         ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 48, 48)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 48, 48)   9248        ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 24, 48)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 24, 48)   9280        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 24, 48)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 24, 48)   36928       ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 12, 48)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 12, 48)  36992       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 128, 12, 48)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 12, 48)  147584      ['dropout_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 6, 48)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 256, 6, 48)   147712      ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 256, 6, 48)   0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 256, 6, 48)   590080      ['dropout_3[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 512, 12, 48)  0          ['conv2d_7[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 24, 48)  0          ['conv2d_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 640, 12, 48)  0           ['conv2d_5[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 320, 24, 48)  0           ['conv2d_3[0][0]',
#                                                                   'up_sampling2d_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 12, 48)  737408      ['concatenate_1[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 160, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'up_sampling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 24, 48)   184384      ['concatenate_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 128, 12, 48)  0           ['conv2d_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 48, 48)   46112       ['concatenate_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 24, 48)   0           ['conv2d_14[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 128, 12, 48)  147584      ['dropout_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 48, 48)   0           ['conv2d_16[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 24, 48)   36928       ['dropout_7[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 24, 48)  0          ['conv2d_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_8[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_15[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 320, 24, 48)  0           ['conv2d_15[0][0]',
#                                                                   'up_sampling2d_5[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 160, 48, 48)  0           ['conv2d_17[0][0]',
#                                                                   'up_sampling2d_6[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 384, 24, 48)  0           ['conv2d_3[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 192, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 24, 48)   221248      ['concatenate_7[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 48, 48)   55328       ['concatenate_9[0][0]']
#
#  dropout_10 (Dropout)           (None, 64, 24, 48)   0           ['conv2d_20[0][0]']
#
#  dropout_11 (Dropout)           (None, 32, 48, 48)   0           ['conv2d_22[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 24, 48)   36928       ['dropout_10[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_11[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_21[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 160, 48, 48)  0           ['conv2d_23[0][0]',
#                                                                   'up_sampling2d_8[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 192, 48, 48)  0           ['conv2d_17[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 224, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 32, 48, 48)   64544       ['concatenate_15[0][0]']
#
#  dropout_13 (Dropout)           (None, 32, 48, 48)   0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 2, 48, 48)    66          ['conv2d_27[0][0]']
#
#  reshape_2 (Reshape)            (None, 2, 2304)      0           ['conv2d_32[0][0]']
#
#  permute_2 (Permute)            (None, 2304, 2)      0           ['reshape_2[0][0]']
#
#  activation_2 (Activation)      (None, 2304, 2)      0           ['permute_2[0][0]']
#
# ==================================================================================================
# Total params: 2,536,418
# Trainable params: 2,536,418
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, Y_train, batch_size=64, epochs=100, verbose=2, shuffle=True, validation_split=0.2, callbacks=[checkpointer])

# 获取训练集和验证集的损失和准确率
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Out:
# Epoch 1/100
# 2024-03-23 15:06:30.933981: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-23 15:06:32.734240: W tensorflow/core/common_runtime/bfc_allocator.cc:360] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 7s - loss: 0.3618 - accuracy: 0.9002 - val_loss: 0.1872 - val_accuracy: 0.9325 - 7s/epoch - 199ms/step
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.2776 - accuracy: 0.9093 - val_loss: 0.1838 - val_accuracy: 0.9325 - 2s/epoch - 51ms/step
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.2741 - accuracy: 0.9093 - val_loss: 0.1817 - val_accuracy: 0.9325 - 2s/epoch - 51ms/step
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.2582 - accuracy: 0.9093 - val_loss: 0.1895 - val_accuracy: 0.9325 - 2s/epoch - 51ms/step
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.2253 - accuracy: 0.9202 - val_loss: 0.1358 - val_accuracy: 0.9495 - 2s/epoch - 51ms/step
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1834 - accuracy: 0.9371 - val_loss: 0.1156 - val_accuracy: 0.9565 - 2s/epoch - 51ms/step
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1657 - accuracy: 0.9422 - val_loss: 0.1072 - val_accuracy: 0.9592 - 2s/epoch - 51ms/step
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1571 - accuracy: 0.9446 - val_loss: 0.1006 - val_accuracy: 0.9632 - 2s/epoch - 52ms/step
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1510 - accuracy: 0.9468 - val_loss: 0.0938 - val_accuracy: 0.9647 - 2s/epoch - 52ms/step
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1413 - accuracy: 0.9496 - val_loss: 0.0914 - val_accuracy: 0.9661 - 2s/epoch - 52ms/step
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1375 - accuracy: 0.9508 - val_loss: 0.0874 - val_accuracy: 0.9684 - 2s/epoch - 51ms/step
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1397 - accuracy: 0.9504 - val_loss: 0.0883 - val_accuracy: 0.9669 - 2s/epoch - 51ms/step
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1338 - accuracy: 0.9521 - val_loss: 0.0817 - val_accuracy: 0.9695 - 2s/epoch - 51ms/step
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1291 - accuracy: 0.9537 - val_loss: 0.0769 - val_accuracy: 0.9713 - 2s/epoch - 51ms/step
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1314 - accuracy: 0.9531 - val_loss: 0.0809 - val_accuracy: 0.9701 - 2s/epoch - 51ms/step
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1263 - accuracy: 0.9546 - val_loss: 0.0760 - val_accuracy: 0.9716 - 2s/epoch - 51ms/step
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1256 - accuracy: 0.9550 - val_loss: 0.0820 - val_accuracy: 0.9693 - 2s/epoch - 51ms/step
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1260 - accuracy: 0.9549 - val_loss: 0.0820 - val_accuracy: 0.9684 - 2s/epoch - 51ms/step
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1227 - accuracy: 0.9561 - val_loss: 0.0751 - val_accuracy: 0.9721 - 2s/epoch - 51ms/step
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1231 - accuracy: 0.9561 - val_loss: 0.0773 - val_accuracy: 0.9711 - 2s/epoch - 51ms/step
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1213 - accuracy: 0.9565 - val_loss: 0.0788 - val_accuracy: 0.9703 - 2s/epoch - 51ms/step
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1197 - accuracy: 0.9572 - val_loss: 0.0770 - val_accuracy: 0.9718 - 2s/epoch - 51ms/step
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1191 - accuracy: 0.9575 - val_loss: 0.0780 - val_accuracy: 0.9710 - 2s/epoch - 51ms/step
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1167 - accuracy: 0.9583 - val_loss: 0.0727 - val_accuracy: 0.9728 - 2s/epoch - 51ms/step
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1161 - accuracy: 0.9586 - val_loss: 0.0818 - val_accuracy: 0.9695 - 2s/epoch - 51ms/step
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1168 - accuracy: 0.9584 - val_loss: 0.0713 - val_accuracy: 0.9733 - 2s/epoch - 51ms/step
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1147 - accuracy: 0.9591 - val_loss: 0.0778 - val_accuracy: 0.9706 - 2s/epoch - 51ms/step
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1154 - accuracy: 0.9588 - val_loss: 0.0718 - val_accuracy: 0.9732 - 2s/epoch - 52ms/step
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1148 - accuracy: 0.9592 - val_loss: 0.0709 - val_accuracy: 0.9729 - 2s/epoch - 52ms/step
# Epoch 30/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1145 - accuracy: 0.9593 - val_loss: 0.0732 - val_accuracy: 0.9725 - 2s/epoch - 51ms/step
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1126 - accuracy: 0.9599 - val_loss: 0.0800 - val_accuracy: 0.9700 - 2s/epoch - 52ms/step
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1143 - accuracy: 0.9594 - val_loss: 0.0720 - val_accuracy: 0.9729 - 2s/epoch - 52ms/step
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1104 - accuracy: 0.9607 - val_loss: 0.0729 - val_accuracy: 0.9725 - 2s/epoch - 51ms/step
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1095 - accuracy: 0.9609 - val_loss: 0.0718 - val_accuracy: 0.9726 - 2s/epoch - 51ms/step
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1091 - accuracy: 0.9611 - val_loss: 0.0723 - val_accuracy: 0.9720 - 2s/epoch - 51ms/step
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1090 - accuracy: 0.9610 - val_loss: 0.0724 - val_accuracy: 0.9720 - 2s/epoch - 51ms/step
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1077 - accuracy: 0.9615 - val_loss: 0.0697 - val_accuracy: 0.9742 - 2s/epoch - 51ms/step
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1075 - accuracy: 0.9615 - val_loss: 0.0706 - val_accuracy: 0.9732 - 2s/epoch - 51ms/step
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1057 - accuracy: 0.9623 - val_loss: 0.0677 - val_accuracy: 0.9747 - 2s/epoch - 51ms/step
# Epoch 40/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1055 - accuracy: 0.9625 - val_loss: 0.0692 - val_accuracy: 0.9738 - 2s/epoch - 51ms/step
# Epoch 41/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1038 - accuracy: 0.9629 - val_loss: 0.0676 - val_accuracy: 0.9746 - 2s/epoch - 51ms/step
# Epoch 42/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1043 - accuracy: 0.9628 - val_loss: 0.0775 - val_accuracy: 0.9693 - 2s/epoch - 52ms/step
# Epoch 43/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1060 - accuracy: 0.9622 - val_loss: 0.0730 - val_accuracy: 0.9721 - 2s/epoch - 51ms/step
# Epoch 44/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1044 - accuracy: 0.9627 - val_loss: 0.0698 - val_accuracy: 0.9731 - 2s/epoch - 52ms/step
# Epoch 45/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1044 - accuracy: 0.9629 - val_loss: 0.0722 - val_accuracy: 0.9727 - 2s/epoch - 51ms/step
# Epoch 46/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1036 - accuracy: 0.9630 - val_loss: 0.0772 - val_accuracy: 0.9708 - 2s/epoch - 51ms/step
# Epoch 47/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1028 - accuracy: 0.9633 - val_loss: 0.0778 - val_accuracy: 0.9713 - 2s/epoch - 51ms/step
# Epoch 48/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1011 - accuracy: 0.9638 - val_loss: 0.0707 - val_accuracy: 0.9738 - 2s/epoch - 51ms/step
# Epoch 49/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1012 - accuracy: 0.9638 - val_loss: 0.0723 - val_accuracy: 0.9724 - 2s/epoch - 51ms/step
# Epoch 50/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.1012 - accuracy: 0.9638 - val_loss: 0.0720 - val_accuracy: 0.9721 - 2s/epoch - 51ms/step
# Epoch 51/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0997 - accuracy: 0.9643 - val_loss: 0.0752 - val_accuracy: 0.9719 - 2s/epoch - 52ms/step
# Epoch 52/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0990 - accuracy: 0.9647 - val_loss: 0.0701 - val_accuracy: 0.9735 - 2s/epoch - 53ms/step
# Epoch 53/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0995 - accuracy: 0.9644 - val_loss: 0.0708 - val_accuracy: 0.9733 - 2s/epoch - 52ms/step
# Epoch 54/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0992 - accuracy: 0.9645 - val_loss: 0.0726 - val_accuracy: 0.9730 - 2s/epoch - 52ms/step
# Epoch 55/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0978 - accuracy: 0.9649 - val_loss: 0.0703 - val_accuracy: 0.9738 - 2s/epoch - 52ms/step
# Epoch 56/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0975 - accuracy: 0.9652 - val_loss: 0.0734 - val_accuracy: 0.9721 - 2s/epoch - 52ms/step
# Epoch 57/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0975 - accuracy: 0.9649 - val_loss: 0.0732 - val_accuracy: 0.9723 - 2s/epoch - 52ms/step
# Epoch 58/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0974 - accuracy: 0.9651 - val_loss: 0.0729 - val_accuracy: 0.9733 - 2s/epoch - 52ms/step
# Epoch 59/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0962 - accuracy: 0.9654 - val_loss: 0.0744 - val_accuracy: 0.9725 - 2s/epoch - 52ms/step
# Epoch 60/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0955 - accuracy: 0.9657 - val_loss: 0.0734 - val_accuracy: 0.9724 - 2s/epoch - 52ms/step
# Epoch 61/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0963 - accuracy: 0.9654 - val_loss: 0.0742 - val_accuracy: 0.9731 - 2s/epoch - 52ms/step
# Epoch 62/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0951 - accuracy: 0.9658 - val_loss: 0.0701 - val_accuracy: 0.9733 - 2s/epoch - 52ms/step
# Epoch 63/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0981 - accuracy: 0.9648 - val_loss: 0.0805 - val_accuracy: 0.9692 - 2s/epoch - 51ms/step
# Epoch 64/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0957 - accuracy: 0.9656 - val_loss: 0.0831 - val_accuracy: 0.9684 - 2s/epoch - 52ms/step
# Epoch 65/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0937 - accuracy: 0.9662 - val_loss: 0.0746 - val_accuracy: 0.9726 - 2s/epoch - 52ms/step
# Epoch 66/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0932 - accuracy: 0.9665 - val_loss: 0.0779 - val_accuracy: 0.9714 - 2s/epoch - 52ms/step
# Epoch 67/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0921 - accuracy: 0.9667 - val_loss: 0.0753 - val_accuracy: 0.9720 - 2s/epoch - 52ms/step
# Epoch 68/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0920 - accuracy: 0.9668 - val_loss: 0.0766 - val_accuracy: 0.9710 - 2s/epoch - 52ms/step
# Epoch 69/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0923 - accuracy: 0.9666 - val_loss: 0.0768 - val_accuracy: 0.9721 - 2s/epoch - 51ms/step
# Epoch 70/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0916 - accuracy: 0.9668 - val_loss: 0.0755 - val_accuracy: 0.9718 - 2s/epoch - 51ms/step
# Epoch 71/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0926 - accuracy: 0.9666 - val_loss: 0.0778 - val_accuracy: 0.9708 - 2s/epoch - 51ms/step
# Epoch 72/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0917 - accuracy: 0.9668 - val_loss: 0.0812 - val_accuracy: 0.9696 - 2s/epoch - 51ms/step
# Epoch 73/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0896 - accuracy: 0.9675 - val_loss: 0.0795 - val_accuracy: 0.9714 - 2s/epoch - 51ms/step
# Epoch 74/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0905 - accuracy: 0.9672 - val_loss: 0.0858 - val_accuracy: 0.9696 - 2s/epoch - 51ms/step
# Epoch 75/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0914 - accuracy: 0.9669 - val_loss: 0.0746 - val_accuracy: 0.9735 - 2s/epoch - 52ms/step
# Epoch 76/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0885 - accuracy: 0.9679 - val_loss: 0.0787 - val_accuracy: 0.9708 - 2s/epoch - 52ms/step
# Epoch 77/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0884 - accuracy: 0.9679 - val_loss: 0.0834 - val_accuracy: 0.9699 - 2s/epoch - 52ms/step
# Epoch 78/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0880 - accuracy: 0.9679 - val_loss: 0.0798 - val_accuracy: 0.9719 - 2s/epoch - 51ms/step
# Epoch 79/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0871 - accuracy: 0.9682 - val_loss: 0.0793 - val_accuracy: 0.9730 - 2s/epoch - 51ms/step
# Epoch 80/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0881 - accuracy: 0.9681 - val_loss: 0.0768 - val_accuracy: 0.9733 - 2s/epoch - 51ms/step
# Epoch 81/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0887 - accuracy: 0.9677 - val_loss: 0.0809 - val_accuracy: 0.9729 - 2s/epoch - 51ms/step
# Epoch 82/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0886 - accuracy: 0.9677 - val_loss: 0.0799 - val_accuracy: 0.9710 - 2s/epoch - 52ms/step
# Epoch 83/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0864 - accuracy: 0.9684 - val_loss: 0.0826 - val_accuracy: 0.9713 - 2s/epoch - 51ms/step
# Epoch 84/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0860 - accuracy: 0.9685 - val_loss: 0.0793 - val_accuracy: 0.9725 - 2s/epoch - 51ms/step
# Epoch 85/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0847 - accuracy: 0.9690 - val_loss: 0.0832 - val_accuracy: 0.9708 - 2s/epoch - 51ms/step
# Epoch 86/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0844 - accuracy: 0.9692 - val_loss: 0.0824 - val_accuracy: 0.9704 - 2s/epoch - 51ms/step
# Epoch 87/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0845 - accuracy: 0.9690 - val_loss: 0.0889 - val_accuracy: 0.9692 - 2s/epoch - 51ms/step
# Epoch 88/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0837 - accuracy: 0.9692 - val_loss: 0.0852 - val_accuracy: 0.9713 - 2s/epoch - 51ms/step
# Epoch 89/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0845 - accuracy: 0.9690 - val_loss: 0.0840 - val_accuracy: 0.9712 - 2s/epoch - 51ms/step
# Epoch 90/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0842 - accuracy: 0.9692 - val_loss: 0.0789 - val_accuracy: 0.9718 - 2s/epoch - 51ms/step
# Epoch 91/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0830 - accuracy: 0.9696 - val_loss: 0.0878 - val_accuracy: 0.9701 - 2s/epoch - 51ms/step
# Epoch 92/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0815 - accuracy: 0.9699 - val_loss: 0.0913 - val_accuracy: 0.9684 - 2s/epoch - 51ms/step
# Epoch 93/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0831 - accuracy: 0.9696 - val_loss: 0.0895 - val_accuracy: 0.9693 - 2s/epoch - 52ms/step
# Epoch 94/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0831 - accuracy: 0.9695 - val_loss: 0.0845 - val_accuracy: 0.9698 - 2s/epoch - 52ms/step
# Epoch 95/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0822 - accuracy: 0.9699 - val_loss: 0.0931 - val_accuracy: 0.9693 - 2s/epoch - 52ms/step
# Epoch 96/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0828 - accuracy: 0.9697 - val_loss: 0.0858 - val_accuracy: 0.9706 - 2s/epoch - 52ms/step
# Epoch 97/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0811 - accuracy: 0.9702 - val_loss: 0.0872 - val_accuracy: 0.9697 - 2s/epoch - 51ms/step
# Epoch 98/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0805 - accuracy: 0.9704 - val_loss: 0.0836 - val_accuracy: 0.9700 - 2s/epoch - 51ms/step
# Epoch 99/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0794 - accuracy: 0.9707 - val_loss: 0.0879 - val_accuracy: 0.9698 - 2s/epoch - 51ms/step
# Epoch 100/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 2s - loss: 0.0809 - accuracy: 0.9702 - val_loss: 0.0875 - val_accuracy: 0.9687 - 2s/epoch - 51ms/step

# %%
imgs = cv2.imread(r'DRIVE/test/images/01_test.tif')[...,1] #the G channel
imgs = cv2.resize(imgs,(img_x, img_y))
manuals = np.asarray(Image.open(r'DRIVE/test/1st_manual/01_manual1.gif'))
X_test = imgs.astype('float32')/255.
Y_test = manuals.astype('float32')/255.
X_test = np.array([[X_test[v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
# model.load_weights('best_weights.h5')
Y_pred = model.predict(X_test)
Y_pred = Y_pred[...,0].reshape(img_x//dx,img_y//dx,dx,dx)
Y_pred = [Y_pred[:,v,...] for v in range(img_x//dx)]
Y_pred = np.concatenate(np.concatenate(Y_pred,axis=1),axis=1)
Y_pred = cv2.resize(Y_pred,(Y_test.shape[1], Y_test.shape[0]))
# Out:
# 5/5 [==============================] - 1s 50ms/step

# %%
plt.figure(figsize=(6,6))
plt.imshow(Y_pred)
plt.savefig('unetpp_L3_predicted_image.png')  # 保存预测的图像
plt.close()  # 关闭当前图形以释放内存

plt.figure(figsize=(6,6))
plt.imshow(Y_test)
plt.savefig('unetpp_L3_ground_truth_image.png')  # 保存真实的图像
plt.close()  # 关闭当前图形以释放内存

# %%
import matplotlib.pyplot as plt

image1 = plt.imread('unetpp_L3_predicted_image.png')
image2 = plt.imread('unetpp_L3_ground_truth_image.png')

fig = plt.figure()
plt.title("left is predicted, right is original")

ax1 = fig.add_subplot(1, 2, 1)
ax1.imshow(image1)
ax1.axis('off')  # 关闭坐标轴

ax2 = fig.add_subplot(1, 2, 2)
ax2.imshow(image2)
ax2.axis('off')  # 关闭坐标轴

plt.tight_layout()

plt.savefig('merged_unetpp_L3_image.png')
plt.show()

# %%
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('unetpp_L3_loss.png')
plt.show()

plt.plot(epochs, train_acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.savefig('unetpp_L3_acc.png')
plt.show()
