# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, UpSampling2D, Reshape, Permute, Activation, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
# Out:
# 2024-03-23 15:19:30.296348: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-23 15:19:31.614066: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-23 15:19:32.216618: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22310 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6

# %%
img_x, img_y = (576, 576)
dx = 48
filelst = os.listdir(r'DRIVE/training/images/')
filelst = ['DRIVE/training/images/'+v for v in filelst]
imgs = [cv2.imread(file) for file in filelst]
filelst = os.listdir(r'DRIVE/training/1st_manual/')
filelst = ['DRIVE/training/1st_manual/'+v for v in filelst]
manuals = [np.asarray(Image.open(file)) for file in filelst]
imgs = [cv2.resize(v,(img_x, img_y)) for v in imgs]
manuals = [cv2.resize(v,(img_x, img_y)) for v in manuals]
X_train = np.array(imgs)  
Y_train = np.array(manuals)
X_train = X_train.astype('float32')/255.
Y_train = Y_train.astype('float32')/255.
X_train = X_train[...,1] # the G channel
X_train = np.array([[X_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
Y_train = np.array([[Y_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx*dx)[...,np.newaxis]
temp = 1-Y_train
Y_train = np.concatenate([Y_train,temp],axis=2)

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)


def conv_block(input_tensor, num_filters):
    """构造一个简单的卷积块，包含两个卷积层"""
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(input_tensor)
    x = Dropout(0.2)(x)
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(x)
    return x

def unet_pp(n_ch, patch_height, patch_width):
    inputs = Input(shape=(n_ch, patch_height, patch_width))

    # 编码路径
    x00 = conv_block(inputs, 32)
    p0 = MaxPooling2D((2, 2))(x00)
    x10 = conv_block(p0, 64)
    p1 = MaxPooling2D((2, 2))(x10)
    x20 = conv_block(p1, 128)
    p2 = MaxPooling2D((2, 2))(x20)
    x30 = conv_block(p2, 256)
    p3 = MaxPooling2D((2, 2))(x30)
    x40 = conv_block(p3, 512) # 最底层
    
    # wtf 纯手写中间层啊，草
    x40_up = UpSampling2D(size=(2, 2))(x40)
    x40_up = concatenate([x30,x40_up],axis=1)
    x31 = conv_block(x40_up, 256)
    
    x30_up = UpSampling2D(size=(2, 2))(x30)
    x30_up = concatenate([x20,x30_up],axis=1)
    x21 = conv_block(x30_up, 128)
    
    x20_up = UpSampling2D(size=(2, 2))(x20)
    x20_up = concatenate([x10,x20_up],axis=1)
    x11 = conv_block(x20_up, 64)
    
    x10_up = UpSampling2D(size=(2, 2))(x10)
    x10_up = concatenate([x00,x10_up],axis=1)
    x01 = conv_block(x10_up, 32)
    
    x31_up = UpSampling2D(size=(2, 2))(x31)
    x31_up = concatenate([x21,x31_up],axis=1)
    x31_up = concatenate([x20,x31_up],axis=1)
    x22 = conv_block(x31_up, 128)
    
    x21_up = UpSampling2D(size=(2, 2))(x21)
    x21_up = concatenate([x11,x21_up],axis=1)
    x21_up = concatenate([x10,x21_up],axis=1)
    x12 = conv_block(x21_up, 64)
    
    x11_up = UpSampling2D(size=(2, 2))(x11)
    x11_up = concatenate([x01,x11_up],axis=1)
    x11_up = concatenate([x00,x11_up],axis=1)
    x02 = conv_block(x11_up, 32)
    
    x22_up = UpSampling2D(size=(2, 2))(x22)
    x22_up = concatenate([x12,x22_up],axis=1)
    x22_up = concatenate([x11,x22_up],axis=1)
    x22_up = concatenate([x10,x22_up],axis=1)
    x13 = conv_block(x22_up, 64)
    
    x12_up = UpSampling2D(size=(2, 2))(x12)
    x12_up = concatenate([x02,x12_up],axis=1)
    x12_up = concatenate([x01,x12_up],axis=1)
    x12_up = concatenate([x00,x12_up],axis=1)
    x03 = conv_block(x12_up, 32)
    
    x13_up = UpSampling2D(size=(2, 2))(x13)
    x13_up = concatenate([x03,x13_up],axis=1)
    x13_up = concatenate([x02,x13_up],axis=1)
    x13_up = concatenate([x01,x13_up],axis=1)
    x13_up = concatenate([x00,x13_up],axis=1)
    x04 = conv_block(x13_up, 32)
    
    # 最终层
    final_1 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x01)
    final_1 = Reshape((2,patch_height*patch_width))(final_1)
    final_1 = Permute((2,1))(final_1)
    final_1 = Activation('softmax')(final_1)
    
    final_2 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x02)
    final_2 = Reshape((2,patch_height*patch_width))(final_2)
    final_2 = Permute((2,1))(final_2)
    final_2 = Activation('softmax')(final_2)
    
    final_3 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x03)
    final_3 = Reshape((2,patch_height*patch_width))(final_3)
    final_3 = Permute((2,1))(final_3)
    final_3 = Activation('softmax')(final_3)
    
    final_4 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x04)
    final_4 = Reshape((2,patch_height*patch_width))(final_4)
    final_4 = Permute((2,1))(final_4)
    final_4 = Activation('softmax')(final_4)
    
    final = [final_1, final_2, final_3, final_4]
    
    # Unet++ L4到L1需要manual modification。
    model = Model(inputs=inputs, outputs=final_2)

    return model
# Out:
# X_train shape: (2880, 1, 48, 48)
# Y_train shape: (2880, 2304, 2)

# %%
# 以下是训练L2的

# %%
model = unet_pp(X_train.shape[1],X_train.shape[2],X_train.shape[3])
model.summary()

# mode = 'max'
checkpointer = ModelCheckpoint(filepath='best_weights.h5', verbose=1, monitor='val_acc', mode='auto', save_best_only=True)
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# 2024-03-23 15:19:45.662742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22310 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1, 48, 48)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 48, 48)   320         ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 48, 48)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 48, 48)   9248        ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 24, 48)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 24, 48)   9280        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 24, 48)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 24, 48)   36928       ['dropout_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 12, 48)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 128, 12, 48)  36992       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 128, 12, 48)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 12, 48)  147584      ['dropout_2[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 256, 24, 48)  0          ['conv2d_5[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 320, 24, 48)  0           ['conv2d_3[0][0]',
#                                                                   'up_sampling2d_2[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 160, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'up_sampling2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 24, 48)   184384      ['concatenate_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 48, 48)   46112       ['concatenate_3[0][0]']
#
#  dropout_7 (Dropout)            (None, 64, 24, 48)   0           ['conv2d_14[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 48, 48)   0           ['conv2d_16[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 24, 48)   36928       ['dropout_7[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_8[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_15[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 160, 48, 48)  0           ['conv2d_17[0][0]',
#                                                                   'up_sampling2d_6[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 192, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 48, 48)   55328       ['concatenate_9[0][0]']
#
#  dropout_11 (Dropout)           (None, 32, 48, 48)   0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_11[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 2, 48, 48)    66          ['conv2d_23[0][0]']
#
#  reshape_1 (Reshape)            (None, 2, 2304)      0           ['conv2d_31[0][0]']
#
#  permute_1 (Permute)            (None, 2304, 2)      0           ['reshape_1[0][0]']
#
#  activation_1 (Activation)      (None, 2304, 2)      0           ['permute_1[0][0]']
#
# ==================================================================================================
# Total params: 581,666
# Trainable params: 581,666
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, Y_train, batch_size=64, epochs=100, verbose=2, shuffle=True, validation_split=0.2, callbacks=[checkpointer])

# 获取训练集和验证集的损失和准确率
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Out:
# Epoch 1/100
# 2024-03-23 15:19:55.194643: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 5s - loss: 0.3739 - accuracy: 0.8995 - val_loss: 0.1882 - val_accuracy: 0.9325 - 5s/epoch - 139ms/step
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.2790 - accuracy: 0.9093 - val_loss: 0.1867 - val_accuracy: 0.9325 - 1s/epoch - 28ms/step
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.2729 - accuracy: 0.9093 - val_loss: 0.1794 - val_accuracy: 0.9325 - 999ms/epoch - 28ms/step
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.2471 - accuracy: 0.9093 - val_loss: 0.1528 - val_accuracy: 0.9325 - 973ms/epoch - 27ms/step
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.2055 - accuracy: 0.9259 - val_loss: 0.1352 - val_accuracy: 0.9509 - 973ms/epoch - 27ms/step
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1845 - accuracy: 0.9366 - val_loss: 0.1243 - val_accuracy: 0.9544 - 959ms/epoch - 27ms/step
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1894 - accuracy: 0.9356 - val_loss: 0.1189 - val_accuracy: 0.9572 - 976ms/epoch - 27ms/step
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1650 - accuracy: 0.9427 - val_loss: 0.0989 - val_accuracy: 0.9634 - 966ms/epoch - 27ms/step
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1493 - accuracy: 0.9474 - val_loss: 0.0892 - val_accuracy: 0.9670 - 982ms/epoch - 27ms/step
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1428 - accuracy: 0.9494 - val_loss: 0.0863 - val_accuracy: 0.9678 - 995ms/epoch - 28ms/step
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1400 - accuracy: 0.9502 - val_loss: 0.0876 - val_accuracy: 0.9668 - 981ms/epoch - 27ms/step
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1356 - accuracy: 0.9515 - val_loss: 0.0922 - val_accuracy: 0.9658 - 979ms/epoch - 27ms/step
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1339 - accuracy: 0.9521 - val_loss: 0.0849 - val_accuracy: 0.9687 - 966ms/epoch - 27ms/step
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1311 - accuracy: 0.9531 - val_loss: 0.0796 - val_accuracy: 0.9701 - 964ms/epoch - 27ms/step
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1319 - accuracy: 0.9528 - val_loss: 0.0790 - val_accuracy: 0.9706 - 966ms/epoch - 27ms/step
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1290 - accuracy: 0.9539 - val_loss: 0.0842 - val_accuracy: 0.9674 - 962ms/epoch - 27ms/step
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1268 - accuracy: 0.9546 - val_loss: 0.0814 - val_accuracy: 0.9684 - 963ms/epoch - 27ms/step
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1270 - accuracy: 0.9544 - val_loss: 0.0854 - val_accuracy: 0.9660 - 963ms/epoch - 27ms/step
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1267 - accuracy: 0.9546 - val_loss: 0.0810 - val_accuracy: 0.9689 - 963ms/epoch - 27ms/step
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1258 - accuracy: 0.9549 - val_loss: 0.0846 - val_accuracy: 0.9664 - 962ms/epoch - 27ms/step
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1244 - accuracy: 0.9554 - val_loss: 0.0855 - val_accuracy: 0.9658 - 964ms/epoch - 27ms/step
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1246 - accuracy: 0.9554 - val_loss: 0.0900 - val_accuracy: 0.9640 - 965ms/epoch - 27ms/step
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1229 - accuracy: 0.9561 - val_loss: 0.0902 - val_accuracy: 0.9640 - 961ms/epoch - 27ms/step
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1208 - accuracy: 0.9564 - val_loss: 0.0899 - val_accuracy: 0.9646 - 960ms/epoch - 27ms/step
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1209 - accuracy: 0.9567 - val_loss: 0.0858 - val_accuracy: 0.9658 - 959ms/epoch - 27ms/step
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1202 - accuracy: 0.9570 - val_loss: 0.0882 - val_accuracy: 0.9651 - 967ms/epoch - 27ms/step
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1196 - accuracy: 0.9571 - val_loss: 0.0888 - val_accuracy: 0.9641 - 962ms/epoch - 27ms/step
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1169 - accuracy: 0.9580 - val_loss: 0.0796 - val_accuracy: 0.9689 - 962ms/epoch - 27ms/step
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1179 - accuracy: 0.9576 - val_loss: 0.0874 - val_accuracy: 0.9650 - 967ms/epoch - 27ms/step
# Epoch 30/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1186 - accuracy: 0.9575 - val_loss: 0.0854 - val_accuracy: 0.9658 - 966ms/epoch - 27ms/step
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1155 - accuracy: 0.9585 - val_loss: 0.0832 - val_accuracy: 0.9669 - 970ms/epoch - 27ms/step
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1152 - accuracy: 0.9586 - val_loss: 0.0927 - val_accuracy: 0.9629 - 981ms/epoch - 27ms/step
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1152 - accuracy: 0.9587 - val_loss: 0.0885 - val_accuracy: 0.9649 - 977ms/epoch - 27ms/step
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1146 - accuracy: 0.9589 - val_loss: 0.0935 - val_accuracy: 0.9631 - 972ms/epoch - 27ms/step
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1137 - accuracy: 0.9592 - val_loss: 0.0921 - val_accuracy: 0.9643 - 965ms/epoch - 27ms/step
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1129 - accuracy: 0.9595 - val_loss: 0.0907 - val_accuracy: 0.9646 - 987ms/epoch - 27ms/step
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1127 - accuracy: 0.9594 - val_loss: 0.0906 - val_accuracy: 0.9635 - 970ms/epoch - 27ms/step
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1124 - accuracy: 0.9596 - val_loss: 0.0926 - val_accuracy: 0.9630 - 985ms/epoch - 27ms/step
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1129 - accuracy: 0.9597 - val_loss: 0.0952 - val_accuracy: 0.9631 - 1s/epoch - 29ms/step
# Epoch 40/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1116 - accuracy: 0.9600 - val_loss: 0.0914 - val_accuracy: 0.9642 - 1s/epoch - 28ms/step
# Epoch 41/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1125 - accuracy: 0.9598 - val_loss: 0.0930 - val_accuracy: 0.9627 - 1s/epoch - 29ms/step
# Epoch 42/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1112 - accuracy: 0.9601 - val_loss: 0.0907 - val_accuracy: 0.9645 - 1s/epoch - 28ms/step
# Epoch 43/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1104 - accuracy: 0.9604 - val_loss: 0.0992 - val_accuracy: 0.9626 - 1s/epoch - 28ms/step
# Epoch 44/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1098 - accuracy: 0.9606 - val_loss: 0.0903 - val_accuracy: 0.9654 - 996ms/epoch - 28ms/step
# Epoch 45/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1093 - accuracy: 0.9609 - val_loss: 0.0869 - val_accuracy: 0.9655 - 996ms/epoch - 28ms/step
# Epoch 46/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1079 - accuracy: 0.9613 - val_loss: 0.0936 - val_accuracy: 0.9640 - 990ms/epoch - 28ms/step
# Epoch 47/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1085 - accuracy: 0.9611 - val_loss: 0.0893 - val_accuracy: 0.9659 - 996ms/epoch - 28ms/step
# Epoch 48/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1093 - accuracy: 0.9609 - val_loss: 0.0999 - val_accuracy: 0.9625 - 998ms/epoch - 28ms/step
# Epoch 49/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1085 - accuracy: 0.9612 - val_loss: 0.1007 - val_accuracy: 0.9625 - 973ms/epoch - 27ms/step
# Epoch 50/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1079 - accuracy: 0.9613 - val_loss: 0.1048 - val_accuracy: 0.9619 - 979ms/epoch - 27ms/step
# Epoch 51/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1074 - accuracy: 0.9615 - val_loss: 0.0907 - val_accuracy: 0.9646 - 996ms/epoch - 28ms/step
# Epoch 52/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1069 - accuracy: 0.9618 - val_loss: 0.0963 - val_accuracy: 0.9638 - 987ms/epoch - 27ms/step
# Epoch 53/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1057 - accuracy: 0.9621 - val_loss: 0.1087 - val_accuracy: 0.9614 - 995ms/epoch - 28ms/step
# Epoch 54/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.1033 - val_accuracy: 0.9614 - 987ms/epoch - 27ms/step
# Epoch 55/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1052 - accuracy: 0.9624 - val_loss: 0.1012 - val_accuracy: 0.9632 - 977ms/epoch - 27ms/step
# Epoch 56/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1051 - accuracy: 0.9623 - val_loss: 0.0957 - val_accuracy: 0.9641 - 971ms/epoch - 27ms/step
# Epoch 57/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1040 - accuracy: 0.9628 - val_loss: 0.1006 - val_accuracy: 0.9636 - 966ms/epoch - 27ms/step
# Epoch 58/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1047 - accuracy: 0.9624 - val_loss: 0.1061 - val_accuracy: 0.9622 - 964ms/epoch - 27ms/step
# Epoch 59/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1036 - accuracy: 0.9629 - val_loss: 0.1018 - val_accuracy: 0.9613 - 975ms/epoch - 27ms/step
# Epoch 60/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1059 - accuracy: 0.9622 - val_loss: 0.1065 - val_accuracy: 0.9628 - 967ms/epoch - 27ms/step
# Epoch 61/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1027 - accuracy: 0.9632 - val_loss: 0.0951 - val_accuracy: 0.9642 - 969ms/epoch - 27ms/step
# Epoch 62/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1029 - accuracy: 0.9631 - val_loss: 0.0943 - val_accuracy: 0.9658 - 968ms/epoch - 27ms/step
# Epoch 63/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1013 - accuracy: 0.9637 - val_loss: 0.1036 - val_accuracy: 0.9631 - 971ms/epoch - 27ms/step
# Epoch 64/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1022 - accuracy: 0.9634 - val_loss: 0.1153 - val_accuracy: 0.9604 - 977ms/epoch - 27ms/step
# Epoch 65/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1028 - accuracy: 0.9631 - val_loss: 0.0993 - val_accuracy: 0.9633 - 966ms/epoch - 27ms/step
# Epoch 66/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1018 - accuracy: 0.9636 - val_loss: 0.1085 - val_accuracy: 0.9617 - 973ms/epoch - 27ms/step
# Epoch 67/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1015 - accuracy: 0.9635 - val_loss: 0.1062 - val_accuracy: 0.9618 - 979ms/epoch - 27ms/step
# Epoch 68/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1001 - accuracy: 0.9641 - val_loss: 0.0964 - val_accuracy: 0.9645 - 988ms/epoch - 27ms/step
# Epoch 69/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1000 - accuracy: 0.9641 - val_loss: 0.0985 - val_accuracy: 0.9635 - 994ms/epoch - 28ms/step
# Epoch 70/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1010 - accuracy: 0.9639 - val_loss: 0.0974 - val_accuracy: 0.9638 - 974ms/epoch - 27ms/step
# Epoch 71/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0993 - accuracy: 0.9643 - val_loss: 0.1022 - val_accuracy: 0.9638 - 983ms/epoch - 27ms/step
# Epoch 72/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0989 - accuracy: 0.9645 - val_loss: 0.1061 - val_accuracy: 0.9619 - 959ms/epoch - 27ms/step
# Epoch 73/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0991 - accuracy: 0.9645 - val_loss: 0.0985 - val_accuracy: 0.9636 - 966ms/epoch - 27ms/step
# Epoch 74/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0989 - accuracy: 0.9646 - val_loss: 0.0990 - val_accuracy: 0.9645 - 966ms/epoch - 27ms/step
# Epoch 75/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0992 - accuracy: 0.9645 - val_loss: 0.1024 - val_accuracy: 0.9627 - 963ms/epoch - 27ms/step
# Epoch 76/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0978 - accuracy: 0.9649 - val_loss: 0.1083 - val_accuracy: 0.9619 - 965ms/epoch - 27ms/step
# Epoch 77/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0992 - accuracy: 0.9644 - val_loss: 0.1116 - val_accuracy: 0.9613 - 965ms/epoch - 27ms/step
# Epoch 78/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0983 - accuracy: 0.9647 - val_loss: 0.1063 - val_accuracy: 0.9625 - 963ms/epoch - 27ms/step
# Epoch 79/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0978 - accuracy: 0.9648 - val_loss: 0.1097 - val_accuracy: 0.9623 - 965ms/epoch - 27ms/step
# Epoch 80/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0986 - accuracy: 0.9647 - val_loss: 0.0975 - val_accuracy: 0.9640 - 968ms/epoch - 27ms/step
# Epoch 81/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0973 - accuracy: 0.9650 - val_loss: 0.1041 - val_accuracy: 0.9638 - 964ms/epoch - 27ms/step
# Epoch 82/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0961 - accuracy: 0.9654 - val_loss: 0.1077 - val_accuracy: 0.9625 - 957ms/epoch - 27ms/step
# Epoch 83/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0964 - accuracy: 0.9653 - val_loss: 0.0999 - val_accuracy: 0.9647 - 965ms/epoch - 27ms/step
# Epoch 84/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0970 - accuracy: 0.9651 - val_loss: 0.1035 - val_accuracy: 0.9646 - 962ms/epoch - 27ms/step
# Epoch 85/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0955 - accuracy: 0.9656 - val_loss: 0.1101 - val_accuracy: 0.9625 - 959ms/epoch - 27ms/step
# Epoch 86/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0953 - accuracy: 0.9656 - val_loss: 0.1005 - val_accuracy: 0.9653 - 974ms/epoch - 27ms/step
# Epoch 87/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0964 - accuracy: 0.9653 - val_loss: 0.1067 - val_accuracy: 0.9628 - 972ms/epoch - 27ms/step
# Epoch 88/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0955 - accuracy: 0.9657 - val_loss: 0.1094 - val_accuracy: 0.9634 - 988ms/epoch - 27ms/step
# Epoch 89/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0962 - accuracy: 0.9654 - val_loss: 0.1031 - val_accuracy: 0.9631 - 989ms/epoch - 27ms/step
# Epoch 90/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0950 - accuracy: 0.9659 - val_loss: 0.1007 - val_accuracy: 0.9655 - 990ms/epoch - 27ms/step
# Epoch 91/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0936 - accuracy: 0.9662 - val_loss: 0.1028 - val_accuracy: 0.9641 - 993ms/epoch - 28ms/step
# Epoch 92/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0940 - accuracy: 0.9661 - val_loss: 0.1040 - val_accuracy: 0.9640 - 973ms/epoch - 27ms/step
# Epoch 93/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0936 - accuracy: 0.9662 - val_loss: 0.1009 - val_accuracy: 0.9640 - 966ms/epoch - 27ms/step
# Epoch 94/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0937 - accuracy: 0.9661 - val_loss: 0.1062 - val_accuracy: 0.9636 - 967ms/epoch - 27ms/step
# Epoch 95/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0943 - accuracy: 0.9661 - val_loss: 0.1073 - val_accuracy: 0.9639 - 963ms/epoch - 27ms/step
# Epoch 96/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0928 - accuracy: 0.9664 - val_loss: 0.0996 - val_accuracy: 0.9658 - 963ms/epoch - 27ms/step
# Epoch 97/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0926 - accuracy: 0.9664 - val_loss: 0.1080 - val_accuracy: 0.9632 - 961ms/epoch - 27ms/step
# Epoch 98/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0925 - accuracy: 0.9665 - val_loss: 0.1049 - val_accuracy: 0.9647 - 961ms/epoch - 27ms/step
# Epoch 99/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0930 - accuracy: 0.9665 - val_loss: 0.1022 - val_accuracy: 0.9645 - 964ms/epoch - 27ms/step
# Epoch 100/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.0928 - accuracy: 0.9664 - val_loss: 0.1121 - val_accuracy: 0.9620 - 958ms/epoch - 27ms/step

# %%
imgs = cv2.imread(r'DRIVE/test/images/01_test.tif')[...,1] #the G channel
imgs = cv2.resize(imgs,(img_x, img_y))
manuals = np.asarray(Image.open(r'DRIVE/test/1st_manual/01_manual1.gif'))
X_test = imgs.astype('float32')/255.
Y_test = manuals.astype('float32')/255.
X_test = np.array([[X_test[v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
# model.load_weights('best_weights.h5')
Y_pred = model.predict(X_test)
Y_pred = Y_pred[...,0].reshape(img_x//dx,img_y//dx,dx,dx)
Y_pred = [Y_pred[:,v,...] for v in range(img_x//dx)]
Y_pred = np.concatenate(np.concatenate(Y_pred,axis=1),axis=1)
Y_pred = cv2.resize(Y_pred,(Y_test.shape[1], Y_test.shape[0]))
# Out:
# 5/5 [==============================] - 0s 27ms/step

# %%
plt.figure(figsize=(6,6))
plt.imshow(Y_pred)
plt.savefig('unetpp_L2_predicted_image.png')  # 保存预测的图像
plt.close()  # 关闭当前图形以释放内存

plt.figure(figsize=(6,6))
plt.imshow(Y_test)
plt.savefig('unetpp_L2_ground_truth_image.png')  # 保存真实的图像
plt.close()  # 关闭当前图形以释放内存

# %%
import matplotlib.pyplot as plt

image1 = plt.imread('unetpp_L2_predicted_image.png')
image2 = plt.imread('unetpp_L2_ground_truth_image.png')

fig = plt.figure()
plt.title("left is predicted, right is original")

ax1 = fig.add_subplot(1, 2, 1)
ax1.imshow(image1)
ax1.axis('off')  # 关闭坐标轴

ax2 = fig.add_subplot(1, 2, 2)
ax2.imshow(image2)
ax2.axis('off')  # 关闭坐标轴

plt.tight_layout()

plt.savefig('merged_unetpp_L2_image.png')
plt.show()

# %%
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('unetpp_L2_loss.png')
plt.show()

plt.plot(epochs, train_acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.savefig('unetpp_L2_acc.png')
plt.show()
