# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import os
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, UpSampling2D, Reshape, Permute, Activation, Dropout
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K

import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)
# Out:
# 2024-03-23 15:26:07.332521: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-03-23 15:26:08.567915: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-23 15:26:09.227584: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22310 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6

# %%
img_x, img_y = (576, 576)
dx = 48
filelst = os.listdir(r'DRIVE/training/images/')
filelst = ['DRIVE/training/images/'+v for v in filelst]
imgs = [cv2.imread(file) for file in filelst]
filelst = os.listdir(r'DRIVE/training/1st_manual/')
filelst = ['DRIVE/training/1st_manual/'+v for v in filelst]
manuals = [np.asarray(Image.open(file)) for file in filelst]
imgs = [cv2.resize(v,(img_x, img_y)) for v in imgs]
manuals = [cv2.resize(v,(img_x, img_y)) for v in manuals]
X_train = np.array(imgs)  
Y_train = np.array(manuals)
X_train = X_train.astype('float32')/255.
Y_train = Y_train.astype('float32')/255.
X_train = X_train[...,1] # the G channel
X_train = np.array([[X_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
Y_train = np.array([[Y_train[:,v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx*dx)[...,np.newaxis]
temp = 1-Y_train
Y_train = np.concatenate([Y_train,temp],axis=2)

# %%
print("X_train shape:", X_train.shape)
print("Y_train shape:", Y_train.shape)


def conv_block(input_tensor, num_filters):
    """构造一个简单的卷积块，包含两个卷积层"""
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(input_tensor)
    x = Dropout(0.2)(x)
    x = Conv2D(num_filters, (3, 3), activation='relu', padding='same', data_format='channels_first')(x)
    return x

def unet_pp(n_ch, patch_height, patch_width):
    inputs = Input(shape=(n_ch, patch_height, patch_width))

    # 编码路径
    x00 = conv_block(inputs, 32)
    p0 = MaxPooling2D((2, 2))(x00)
    x10 = conv_block(p0, 64)
    p1 = MaxPooling2D((2, 2))(x10)
    x20 = conv_block(p1, 128)
    p2 = MaxPooling2D((2, 2))(x20)
    x30 = conv_block(p2, 256)
    p3 = MaxPooling2D((2, 2))(x30)
    x40 = conv_block(p3, 512) # 最底层
    
    # wtf 纯手写中间层啊，草
    x40_up = UpSampling2D(size=(2, 2))(x40)
    x40_up = concatenate([x30,x40_up],axis=1)
    x31 = conv_block(x40_up, 256)
    
    x30_up = UpSampling2D(size=(2, 2))(x30)
    x30_up = concatenate([x20,x30_up],axis=1)
    x21 = conv_block(x30_up, 128)
    
    x20_up = UpSampling2D(size=(2, 2))(x20)
    x20_up = concatenate([x10,x20_up],axis=1)
    x11 = conv_block(x20_up, 64)
    
    x10_up = UpSampling2D(size=(2, 2))(x10)
    x10_up = concatenate([x00,x10_up],axis=1)
    x01 = conv_block(x10_up, 32)
    
    x31_up = UpSampling2D(size=(2, 2))(x31)
    x31_up = concatenate([x21,x31_up],axis=1)
    x31_up = concatenate([x20,x31_up],axis=1)
    x22 = conv_block(x31_up, 128)
    
    x21_up = UpSampling2D(size=(2, 2))(x21)
    x21_up = concatenate([x11,x21_up],axis=1)
    x21_up = concatenate([x10,x21_up],axis=1)
    x12 = conv_block(x21_up, 64)
    
    x11_up = UpSampling2D(size=(2, 2))(x11)
    x11_up = concatenate([x01,x11_up],axis=1)
    x11_up = concatenate([x00,x11_up],axis=1)
    x02 = conv_block(x11_up, 32)
    
    x22_up = UpSampling2D(size=(2, 2))(x22)
    x22_up = concatenate([x12,x22_up],axis=1)
    x22_up = concatenate([x11,x22_up],axis=1)
    x22_up = concatenate([x10,x22_up],axis=1)
    x13 = conv_block(x22_up, 64)
    
    x12_up = UpSampling2D(size=(2, 2))(x12)
    x12_up = concatenate([x02,x12_up],axis=1)
    x12_up = concatenate([x01,x12_up],axis=1)
    x12_up = concatenate([x00,x12_up],axis=1)
    x03 = conv_block(x12_up, 32)
    
    x13_up = UpSampling2D(size=(2, 2))(x13)
    x13_up = concatenate([x03,x13_up],axis=1)
    x13_up = concatenate([x02,x13_up],axis=1)
    x13_up = concatenate([x01,x13_up],axis=1)
    x13_up = concatenate([x00,x13_up],axis=1)
    x04 = conv_block(x13_up, 32)
    
    # 最终层
    final_1 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x01)
    final_1 = Reshape((2,patch_height*patch_width))(final_1)
    final_1 = Permute((2,1))(final_1)
    final_1 = Activation('softmax')(final_1)
    
    final_2 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x02)
    final_2 = Reshape((2,patch_height*patch_width))(final_2)
    final_2 = Permute((2,1))(final_2)
    final_2 = Activation('softmax')(final_2)
    
    final_3 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x03)
    final_3 = Reshape((2,patch_height*patch_width))(final_3)
    final_3 = Permute((2,1))(final_3)
    final_3 = Activation('softmax')(final_3)
    
    final_4 = Conv2D(2,(1,1),activation='relu',padding='same',data_format='channels_first')(x04)
    final_4 = Reshape((2,patch_height*patch_width))(final_4)
    final_4 = Permute((2,1))(final_4)
    final_4 = Activation('softmax')(final_4)
    
    final = [final_1, final_2, final_3, final_4]
    
    # Unet++ L4到L1需要manual modification。
    model = Model(inputs=inputs, outputs=final_1)

    return model
# Out:
# X_train shape: (2880, 1, 48, 48)
# Y_train shape: (2880, 2304, 2)

# %%
# 以下是训练L1的

# %%
model = unet_pp(X_train.shape[1],X_train.shape[2],X_train.shape[3])
model.summary()

# mode = 'max'
checkpointer = ModelCheckpoint(filepath='best_weights.h5', verbose=1, monitor='val_acc', mode='auto', save_best_only=True)
model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# 2024-03-23 15:26:29.463277: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22310 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:56:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 1, 48, 48)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 48, 48)   320         ['input_1[0][0]']
#
#  dropout (Dropout)              (None, 32, 48, 48)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 32, 48, 48)   9248        ['dropout[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 24, 48)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 24, 48)   9280        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 24, 48)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 24, 48)   36928       ['dropout_1[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 48, 48)  0          ['conv2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 160, 48, 48)  0           ['conv2d_1[0][0]',
#                                                                   'up_sampling2d_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 48, 48)   46112       ['concatenate_3[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 48, 48)   0           ['conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 48, 48)   9248        ['dropout_8[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 2, 48, 48)    66          ['conv2d_17[0][0]']
#
#  reshape (Reshape)              (None, 2, 2304)      0           ['conv2d_30[0][0]']
#
#  permute (Permute)              (None, 2304, 2)      0           ['reshape[0][0]']
#
#  activation (Activation)        (None, 2304, 2)      0           ['permute[0][0]']
#
# ==================================================================================================
# Total params: 111,202
# Trainable params: 111,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
history = model.fit(X_train, Y_train, batch_size=64, epochs=100, verbose=2, shuffle=True, validation_split=0.2, callbacks=[checkpointer])

# 获取训练集和验证集的损失和准确率
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Out:
# Epoch 1/100
# 2024-03-23 15:26:38.008529: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 4s - loss: 0.3954 - accuracy: 0.8805 - val_loss: 0.1880 - val_accuracy: 0.9325 - 4s/epoch - 104ms/step
# Epoch 2/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2796 - accuracy: 0.9093 - val_loss: 0.1902 - val_accuracy: 0.9325 - 442ms/epoch - 12ms/step
# Epoch 3/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2769 - accuracy: 0.9093 - val_loss: 0.1845 - val_accuracy: 0.9325 - 450ms/epoch - 13ms/step
# Epoch 4/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2733 - accuracy: 0.9093 - val_loss: 0.1836 - val_accuracy: 0.9325 - 440ms/epoch - 12ms/step
# Epoch 5/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2625 - accuracy: 0.9093 - val_loss: 0.1726 - val_accuracy: 0.9325 - 439ms/epoch - 12ms/step
# Epoch 6/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2331 - accuracy: 0.9141 - val_loss: 0.1599 - val_accuracy: 0.9435 - 445ms/epoch - 12ms/step
# Epoch 7/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.2217 - accuracy: 0.9281 - val_loss: 0.1410 - val_accuracy: 0.9508 - 433ms/epoch - 12ms/step
# Epoch 8/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1861 - accuracy: 0.9383 - val_loss: 0.1193 - val_accuracy: 0.9569 - 436ms/epoch - 12ms/step
# Epoch 9/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1725 - accuracy: 0.9408 - val_loss: 0.1209 - val_accuracy: 0.9582 - 440ms/epoch - 12ms/step
# Epoch 10/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1615 - accuracy: 0.9435 - val_loss: 0.1113 - val_accuracy: 0.9613 - 442ms/epoch - 12ms/step
# Epoch 11/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1547 - accuracy: 0.9453 - val_loss: 0.1081 - val_accuracy: 0.9631 - 442ms/epoch - 12ms/step
# Epoch 12/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1489 - accuracy: 0.9470 - val_loss: 0.1033 - val_accuracy: 0.9644 - 459ms/epoch - 13ms/step
# Epoch 13/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1453 - accuracy: 0.9481 - val_loss: 0.0937 - val_accuracy: 0.9666 - 485ms/epoch - 13ms/step
# Epoch 14/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1423 - accuracy: 0.9492 - val_loss: 0.0883 - val_accuracy: 0.9678 - 481ms/epoch - 13ms/step
# Epoch 15/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1415 - accuracy: 0.9491 - val_loss: 0.0913 - val_accuracy: 0.9673 - 495ms/epoch - 14ms/step
# Epoch 16/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1420 - accuracy: 0.9494 - val_loss: 0.0941 - val_accuracy: 0.9617 - 487ms/epoch - 14ms/step
# Epoch 17/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1410 - accuracy: 0.9496 - val_loss: 0.0853 - val_accuracy: 0.9691 - 468ms/epoch - 13ms/step
# Epoch 18/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1377 - accuracy: 0.9507 - val_loss: 0.0856 - val_accuracy: 0.9691 - 464ms/epoch - 13ms/step
# Epoch 19/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1359 - accuracy: 0.9511 - val_loss: 0.0856 - val_accuracy: 0.9690 - 468ms/epoch - 13ms/step
# Epoch 20/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1338 - accuracy: 0.9519 - val_loss: 0.0849 - val_accuracy: 0.9694 - 471ms/epoch - 13ms/step
# Epoch 21/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1343 - accuracy: 0.9517 - val_loss: 0.0852 - val_accuracy: 0.9691 - 467ms/epoch - 13ms/step
# Epoch 22/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1336 - accuracy: 0.9519 - val_loss: 0.0838 - val_accuracy: 0.9691 - 470ms/epoch - 13ms/step
# Epoch 23/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1344 - accuracy: 0.9516 - val_loss: 0.0872 - val_accuracy: 0.9690 - 463ms/epoch - 13ms/step
# Epoch 24/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1311 - accuracy: 0.9526 - val_loss: 0.0835 - val_accuracy: 0.9698 - 466ms/epoch - 13ms/step
# Epoch 25/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1308 - accuracy: 0.9530 - val_loss: 0.0838 - val_accuracy: 0.9695 - 499ms/epoch - 14ms/step
# Epoch 26/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1296 - accuracy: 0.9531 - val_loss: 0.0873 - val_accuracy: 0.9681 - 476ms/epoch - 13ms/step
# Epoch 27/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1305 - accuracy: 0.9531 - val_loss: 0.0861 - val_accuracy: 0.9685 - 475ms/epoch - 13ms/step
# Epoch 28/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1293 - accuracy: 0.9534 - val_loss: 0.0836 - val_accuracy: 0.9697 - 477ms/epoch - 13ms/step
# Epoch 29/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1301 - accuracy: 0.9530 - val_loss: 0.0830 - val_accuracy: 0.9696 - 494ms/epoch - 14ms/step
# Epoch 30/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1278 - accuracy: 0.9540 - val_loss: 0.0803 - val_accuracy: 0.9706 - 508ms/epoch - 14ms/step
# Epoch 31/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1275 - accuracy: 0.9541 - val_loss: 0.0810 - val_accuracy: 0.9702 - 506ms/epoch - 14ms/step
# Epoch 32/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1261 - accuracy: 0.9545 - val_loss: 0.0832 - val_accuracy: 0.9695 - 506ms/epoch - 14ms/step
# Epoch 33/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1272 - accuracy: 0.9543 - val_loss: 0.0823 - val_accuracy: 0.9701 - 479ms/epoch - 13ms/step
# Epoch 34/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1272 - accuracy: 0.9543 - val_loss: 0.0796 - val_accuracy: 0.9704 - 472ms/epoch - 13ms/step
# Epoch 35/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1257 - accuracy: 0.9546 - val_loss: 0.0804 - val_accuracy: 0.9700 - 475ms/epoch - 13ms/step
# Epoch 36/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1244 - accuracy: 0.9550 - val_loss: 0.0802 - val_accuracy: 0.9707 - 474ms/epoch - 13ms/step
# Epoch 37/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1258 - accuracy: 0.9546 - val_loss: 0.0804 - val_accuracy: 0.9702 - 468ms/epoch - 13ms/step
# Epoch 38/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1272 - accuracy: 0.9544 - val_loss: 0.0811 - val_accuracy: 0.9699 - 477ms/epoch - 13ms/step
# Epoch 39/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1259 - accuracy: 0.9546 - val_loss: 0.0801 - val_accuracy: 0.9705 - 467ms/epoch - 13ms/step
# Epoch 40/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1237 - accuracy: 0.9554 - val_loss: 0.0784 - val_accuracy: 0.9713 - 474ms/epoch - 13ms/step
# Epoch 41/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1233 - accuracy: 0.9554 - val_loss: 0.0789 - val_accuracy: 0.9709 - 475ms/epoch - 13ms/step
# Epoch 42/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1233 - accuracy: 0.9557 - val_loss: 0.0802 - val_accuracy: 0.9705 - 483ms/epoch - 13ms/step
# Epoch 43/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1224 - accuracy: 0.9557 - val_loss: 0.0776 - val_accuracy: 0.9713 - 492ms/epoch - 14ms/step
# Epoch 44/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1227 - accuracy: 0.9557 - val_loss: 0.0795 - val_accuracy: 0.9710 - 500ms/epoch - 14ms/step
# Epoch 45/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1223 - accuracy: 0.9559 - val_loss: 0.0814 - val_accuracy: 0.9696 - 507ms/epoch - 14ms/step
# Epoch 46/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1229 - accuracy: 0.9557 - val_loss: 0.0791 - val_accuracy: 0.9713 - 509ms/epoch - 14ms/step
# Epoch 47/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1220 - accuracy: 0.9560 - val_loss: 0.0811 - val_accuracy: 0.9693 - 483ms/epoch - 13ms/step
# Epoch 48/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1224 - accuracy: 0.9559 - val_loss: 0.0805 - val_accuracy: 0.9708 - 486ms/epoch - 14ms/step
# Epoch 49/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1227 - accuracy: 0.9559 - val_loss: 0.0780 - val_accuracy: 0.9713 - 484ms/epoch - 13ms/step
# Epoch 50/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1229 - accuracy: 0.9559 - val_loss: 0.0778 - val_accuracy: 0.9710 - 502ms/epoch - 14ms/step
# Epoch 51/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1220 - accuracy: 0.9562 - val_loss: 0.0778 - val_accuracy: 0.9720 - 505ms/epoch - 14ms/step
# Epoch 52/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1205 - accuracy: 0.9565 - val_loss: 0.0800 - val_accuracy: 0.9712 - 504ms/epoch - 14ms/step
# Epoch 53/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1201 - accuracy: 0.9567 - val_loss: 0.0818 - val_accuracy: 0.9696 - 505ms/epoch - 14ms/step
# Epoch 54/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1207 - accuracy: 0.9566 - val_loss: 0.0769 - val_accuracy: 0.9716 - 486ms/epoch - 13ms/step
# Epoch 55/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1195 - accuracy: 0.9571 - val_loss: 0.0771 - val_accuracy: 0.9718 - 480ms/epoch - 13ms/step
# Epoch 56/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1200 - accuracy: 0.9567 - val_loss: 0.0767 - val_accuracy: 0.9714 - 482ms/epoch - 13ms/step
# Epoch 57/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1200 - accuracy: 0.9569 - val_loss: 0.0818 - val_accuracy: 0.9694 - 478ms/epoch - 13ms/step
# Epoch 58/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1202 - accuracy: 0.9567 - val_loss: 0.0779 - val_accuracy: 0.9714 - 468ms/epoch - 13ms/step
# Epoch 59/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1181 - accuracy: 0.9575 - val_loss: 0.0778 - val_accuracy: 0.9719 - 477ms/epoch - 13ms/step
# Epoch 60/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1190 - accuracy: 0.9571 - val_loss: 0.0764 - val_accuracy: 0.9717 - 474ms/epoch - 13ms/step
# Epoch 61/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1193 - accuracy: 0.9571 - val_loss: 0.0780 - val_accuracy: 0.9711 - 477ms/epoch - 13ms/step
# Epoch 62/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1187 - accuracy: 0.9574 - val_loss: 0.0775 - val_accuracy: 0.9716 - 479ms/epoch - 13ms/step
# Epoch 63/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1181 - accuracy: 0.9573 - val_loss: 0.0779 - val_accuracy: 0.9711 - 497ms/epoch - 14ms/step
# Epoch 64/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1184 - accuracy: 0.9573 - val_loss: 0.0771 - val_accuracy: 0.9721 - 508ms/epoch - 14ms/step
# Epoch 65/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1184 - accuracy: 0.9574 - val_loss: 0.0778 - val_accuracy: 0.9714 - 494ms/epoch - 14ms/step
# Epoch 66/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1179 - accuracy: 0.9576 - val_loss: 0.0761 - val_accuracy: 0.9720 - 483ms/epoch - 13ms/step
# Epoch 67/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1177 - accuracy: 0.9576 - val_loss: 0.0762 - val_accuracy: 0.9717 - 474ms/epoch - 13ms/step
# Epoch 68/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1179 - accuracy: 0.9576 - val_loss: 0.0763 - val_accuracy: 0.9719 - 473ms/epoch - 13ms/step
# Epoch 69/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1175 - accuracy: 0.9577 - val_loss: 0.0759 - val_accuracy: 0.9727 - 475ms/epoch - 13ms/step
# Epoch 70/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1176 - accuracy: 0.9578 - val_loss: 0.0762 - val_accuracy: 0.9717 - 470ms/epoch - 13ms/step
# Epoch 71/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1200 - accuracy: 0.9571 - val_loss: 0.0792 - val_accuracy: 0.9712 - 464ms/epoch - 13ms/step
# Epoch 72/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1184 - accuracy: 0.9573 - val_loss: 0.0757 - val_accuracy: 0.9720 - 478ms/epoch - 13ms/step
# Epoch 73/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1170 - accuracy: 0.9578 - val_loss: 0.0758 - val_accuracy: 0.9722 - 495ms/epoch - 14ms/step
# Epoch 74/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1164 - accuracy: 0.9582 - val_loss: 0.0766 - val_accuracy: 0.9715 - 504ms/epoch - 14ms/step
# Epoch 75/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1164 - accuracy: 0.9581 - val_loss: 0.0749 - val_accuracy: 0.9724 - 494ms/epoch - 14ms/step
# Epoch 76/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1165 - accuracy: 0.9581 - val_loss: 0.0790 - val_accuracy: 0.9715 - 484ms/epoch - 13ms/step
# Epoch 77/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1169 - accuracy: 0.9579 - val_loss: 0.0744 - val_accuracy: 0.9732 - 479ms/epoch - 13ms/step
# Epoch 78/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1158 - accuracy: 0.9583 - val_loss: 0.0752 - val_accuracy: 0.9730 - 469ms/epoch - 13ms/step
# Epoch 79/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1160 - accuracy: 0.9584 - val_loss: 0.0758 - val_accuracy: 0.9721 - 481ms/epoch - 13ms/step
# Epoch 80/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1171 - accuracy: 0.9579 - val_loss: 0.0749 - val_accuracy: 0.9728 - 469ms/epoch - 13ms/step
# Epoch 81/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1164 - accuracy: 0.9581 - val_loss: 0.0755 - val_accuracy: 0.9717 - 478ms/epoch - 13ms/step
# Epoch 82/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1159 - accuracy: 0.9584 - val_loss: 0.0792 - val_accuracy: 0.9702 - 478ms/epoch - 13ms/step
# Epoch 83/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1159 - accuracy: 0.9584 - val_loss: 0.0758 - val_accuracy: 0.9720 - 478ms/epoch - 13ms/step
# Epoch 84/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1163 - accuracy: 0.9583 - val_loss: 0.0754 - val_accuracy: 0.9722 - 497ms/epoch - 14ms/step
# Epoch 85/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1161 - accuracy: 0.9582 - val_loss: 0.0766 - val_accuracy: 0.9716 - 503ms/epoch - 14ms/step
# Epoch 86/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1149 - accuracy: 0.9587 - val_loss: 0.0737 - val_accuracy: 0.9729 - 498ms/epoch - 14ms/step
# Epoch 87/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1161 - accuracy: 0.9583 - val_loss: 0.0800 - val_accuracy: 0.9700 - 478ms/epoch - 13ms/step
# Epoch 88/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1160 - accuracy: 0.9584 - val_loss: 0.0763 - val_accuracy: 0.9713 - 477ms/epoch - 13ms/step
# Epoch 89/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1163 - accuracy: 0.9582 - val_loss: 0.0788 - val_accuracy: 0.9703 - 482ms/epoch - 13ms/step
# Epoch 90/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1155 - accuracy: 0.9585 - val_loss: 0.0758 - val_accuracy: 0.9727 - 485ms/epoch - 13ms/step
# Epoch 91/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1151 - accuracy: 0.9587 - val_loss: 0.0791 - val_accuracy: 0.9700 - 486ms/epoch - 14ms/step
# Epoch 92/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1171 - accuracy: 0.9578 - val_loss: 0.0797 - val_accuracy: 0.9694 - 481ms/epoch - 13ms/step
# Epoch 93/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1143 - accuracy: 0.9589 - val_loss: 0.0755 - val_accuracy: 0.9718 - 476ms/epoch - 13ms/step
# Epoch 94/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1140 - accuracy: 0.9590 - val_loss: 0.0793 - val_accuracy: 0.9698 - 476ms/epoch - 13ms/step
# Epoch 95/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1144 - accuracy: 0.9589 - val_loss: 0.0756 - val_accuracy: 0.9721 - 476ms/epoch - 13ms/step
# Epoch 96/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1138 - accuracy: 0.9590 - val_loss: 0.0774 - val_accuracy: 0.9722 - 483ms/epoch - 13ms/step
# Epoch 97/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1134 - accuracy: 0.9593 - val_loss: 0.0784 - val_accuracy: 0.9700 - 505ms/epoch - 14ms/step
# Epoch 98/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 1s - loss: 0.1155 - accuracy: 0.9585 - val_loss: 0.0801 - val_accuracy: 0.9695 - 503ms/epoch - 14ms/step
# Epoch 99/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1139 - accuracy: 0.9591 - val_loss: 0.0744 - val_accuracy: 0.9727 - 500ms/epoch - 14ms/step
# Epoch 100/100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 36/36 - 0s - loss: 0.1131 - accuracy: 0.9593 - val_loss: 0.0837 - val_accuracy: 0.9677 - 477ms/epoch - 13ms/step

# %%
imgs = cv2.imread(r'DRIVE/test/images/01_test.tif')[...,1] #the G channel
imgs = cv2.resize(imgs,(img_x, img_y))
manuals = np.asarray(Image.open(r'DRIVE/test/1st_manual/01_manual1.gif'))
X_test = imgs.astype('float32')/255.
Y_test = manuals.astype('float32')/255.
X_test = np.array([[X_test[v*dx:(v+1)*dx, vv*dx:(vv+1)*dx] for v in range(img_y//dx)] for vv in range(img_x//dx)]).reshape(-1,dx,dx)[:,np.newaxis,...]
# model.load_weights('best_weights.h5')
Y_pred = model.predict(X_test)
Y_pred = Y_pred[...,0].reshape(img_x//dx,img_y//dx,dx,dx)
Y_pred = [Y_pred[:,v,...] for v in range(img_x//dx)]
Y_pred = np.concatenate(np.concatenate(Y_pred,axis=1),axis=1)
Y_pred = cv2.resize(Y_pred,(Y_test.shape[1], Y_test.shape[0]))
# Out:
# 5/5 [==============================] - 0s 14ms/step

# %%
plt.figure(figsize=(6,6))
plt.imshow(Y_pred)
plt.savefig('unetpp_L1_predicted_image.png')  # 保存预测的图像
plt.close()  # 关闭当前图形以释放内存

plt.figure(figsize=(6,6))
plt.imshow(Y_test)
plt.savefig('unetpp_L1_ground_truth_image.png')  # 保存真实的图像
plt.close()  # 关闭当前图形以释放内存

# %%
import matplotlib.pyplot as plt

image1 = plt.imread('unetpp_L1_predicted_image.png')
image2 = plt.imread('unetpp_L1_ground_truth_image.png')

fig = plt.figure()
plt.title("left is predicted, right is original")

ax1 = fig.add_subplot(1, 2, 1)
ax1.imshow(image1)
ax1.axis('off')  # 关闭坐标轴

ax2 = fig.add_subplot(1, 2, 2)
ax2.imshow(image2)
ax2.axis('off')  # 关闭坐标轴

plt.tight_layout()

plt.savefig('merged_unetpp_L1_image.png')
plt.show()

# %%
epochs = range(1, len(train_loss) + 1)

plt.plot(epochs, train_loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.savefig('unetpp_L1_loss.png')
plt.show()

plt.plot(epochs, train_acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.savefig('unetpp_L1_acc.png')
plt.show()
